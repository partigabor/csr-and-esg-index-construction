# %%
import pandas as pd
import regex as re
import os, sys
import xml.etree.ElementTree as et
import PyPDF2

path = "data-transcripts" ###

# %%
# a function to walk through all files in a folder and its subfolders
def list_files(dir):                                                                                                  
    r = []                                                                                                            
    subdirs = [x[0] for x in os.walk(dir)]                                                                            
    for subdir in subdirs:                                                                                            
        files = os.walk(subdir).__next__()[2]                                                                             
        if (len(files) > 0):                                                                                          
            for file in files:                                                                                        
                r.append(os.path.join(subdir, file))                                                                         
    return r

# %%
# directory = os.path.join(sys.path[0], path + "\\raw") ### INPUT FOLDER HERE ###
# files_in_dir = list_files(directory)
# files_in_dir
# Out:
# ['c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1004063_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1004063_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10103972_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10103972_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012763_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012763_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012782_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012782_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012785_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012785_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012787_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1012787_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1020948_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1020948_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10221377_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10221377_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10229958_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10229958_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10231130_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10231130_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10276652_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10276652_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10305562_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10305562_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10341258_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10341258_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10353489_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10353489_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10354189_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10354189_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1037620_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1037620_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10382650_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10382650_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10406938_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10406938_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10418964_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10418964_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10426026_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10426026_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1048657_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1048657_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10550671_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10550671_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1065361_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1065361_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1065377_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1065377_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10655690_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10655690_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10659595_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10659595_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10679258_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10679258_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10687439_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10687439_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10689602_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10689602_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10724780_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10724780_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10733834_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10733834_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10748343_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10748343_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10749089_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10749089_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10749091_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10749091_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10781921_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10781921_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10784487_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10784487_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10879997_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10879997_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10888886_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10888886_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10909023_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10909023_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10911177_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10911177_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10935301_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10935301_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10971426_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10971426_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10980324_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\10980324_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11006220_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11006220_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11010367_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11010367_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11011265_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11011265_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11011706_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11011706_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1102148_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1102148_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11031505_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11031505_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11058412_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11058412_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11060027_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11060027_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11061268_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11061268_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11071004_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11071004_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11087732_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11087732_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11091851_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11091851_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11092385_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11092385_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11092392_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11092392_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11092405_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11092405_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11093216_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11093216_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11097096_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11097096_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11097846_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11097846_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11103974_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11103974_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11103977_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11103977_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11107347_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11107347_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11109158_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11109158_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11110695_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11110695_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11119106_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11119106_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11132279_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11132279_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11140220_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11140220_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11143636_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11143636_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11169124_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11169124_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11182428_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11182428_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11184018_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11184018_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11192371_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11192371_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11195825_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11195825_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11196516_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11196516_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11204298_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11204298_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11220315_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11220315_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11220316_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11220316_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11225052_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11225052_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11231748_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11231748_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11237728_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11237728_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11256308_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11256308_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11265653_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11265653_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11266461_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11266461_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11269517_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11269517_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11269782_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11269782_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11273132_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11273132_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11273152_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11273152_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11307423_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11307423_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11307844_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11307844_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11317112_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11317112_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11325204_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11325204_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11355890_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11355890_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11364510_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11364510_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11365728_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11365728_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11397571_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11397571_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1140247_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1140247_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11409211_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11409211_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11434478_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11434478_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11436894_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11436894_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11458913_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11458913_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11463913_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11463913_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11467978_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11467978_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1146929_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1146929_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11479784_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11479784_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11479954_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11479954_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11480186_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11480186_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11480234_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11480234_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11480943_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11480943_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11481344_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11481344_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11481431_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11481431_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11482950_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11482950_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11483156_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11483156_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11483175_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11483175_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11484562_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11484562_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11486161_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11486161_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489004_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489004_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489048_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489048_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489054_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489054_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489157_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489157_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489169_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489169_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489254_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11489254_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11490054_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11490054_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11496168_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11496168_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11496535_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11496535_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11497769_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11497769_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500057_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500057_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500244_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500244_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500392_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500392_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500735_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11500735_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11502165_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11502165_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11503275_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11503275_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11512406_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11512406_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11513583_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11513583_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11514074_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11514074_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11515553_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11515553_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11529553_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11529553_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11535601_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11535601_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11542797_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11542797_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11552449_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11552449_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11571044_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11571044_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11575105_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11575105_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11611770_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11611770_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11632258_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11632258_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11634364_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11634364_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11635206_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11635206_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11635384_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11635384_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11640655_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11640655_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11640709_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11640709_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11641711_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11641711_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642141_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642141_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642455_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642455_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642854_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642854_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642922_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11642922_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11643782_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11643782_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11644016_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11644016_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11646687_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11646687_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11652291_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11652291_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11658543_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11658543_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11658719_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11658719_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11663997_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11663997_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11665794_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11665794_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11672400_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11672400_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11677115_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11677115_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11678094_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11678094_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11679297_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11679297_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11689383_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11689383_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11691145_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11691145_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11721956_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11721956_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11733736_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11733736_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1174161_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1174161_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11755842_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11755842_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11760784_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11760784_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11760848_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11760848_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11773547_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11773547_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11775365_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11775365_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11789507_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11789507_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11814194_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11814194_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11821917_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11821917_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11834860_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11834860_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11836003_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11836003_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11840328_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11840328_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11858277_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11858277_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11869482_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11869482_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11875965_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11875965_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11881418_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11881418_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1189833_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1189833_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1191633_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1191633_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1194934_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1194934_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11963005_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11963005_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11963954_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11963954_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11972725_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11972725_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11996646_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\11996646_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1200947_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1200947_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12040268_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12040268_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12040701_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12040701_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12042080_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12042080_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12042473_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12042473_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1207320_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\1207320_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12078244_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12078244_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12082825_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12082825_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12082830_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12082830_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12083030_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12083030_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12096522_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12096522_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12122504_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12122504_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12123432_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12123432_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12123765_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12123765_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12124388_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12124388_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12125345_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12125345_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12126086_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12126086_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12140641_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12140641_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12141672_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12141672_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12142180_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12142180_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12142754_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12142754_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12144745_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12144745_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12145306_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12145306_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12145925_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12145925_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12158960_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12158960_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12163185_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12163185_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12165172_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12165172_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12169762_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12169762_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12174929_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12174929_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12178603_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12178603_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12180321_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12180321_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12180568_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12180568_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12182076_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12182076_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12182904_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12182904_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12184301_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12184301_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12186863_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12186863_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12189542_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12189542_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12190370_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12190370_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12191799_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12191799_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12193390_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12193390_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12196206_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12196206_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12197085_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12197085_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12197091_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12197091_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12197093_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12197093_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12198850_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12198850_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12199373_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12199373_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12202337_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12202337_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12204079_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12204079_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12204832_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12204832_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12211530_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12211530_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12212023_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12212023_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12212548_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12212548_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12213144_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12213144_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215052_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215052_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215573_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215573_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215770_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215770_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215879_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12215879_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12216649_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12216649_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12220940_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12220940_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12221061_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12221061_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12221582_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12221582_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12222822_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12222822_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12223159_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12223159_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12223471_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12223471_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12223974_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12223974_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12224970_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12224970_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12228170_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12228170_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12228921_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12228921_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12229028_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12229028_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12230021_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12230021_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12230139_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12230139_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12230311_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12230311_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12231293_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12231293_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12231388_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12231388_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12231679_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12231679_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12232342_T.pdf',
# ...
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348318_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348334_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348334_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348343_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348343_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348348_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348348_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348544_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12348544_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349329_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349329_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349721_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349721_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349827_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349827_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349885_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12349885_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350134_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350134_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350157_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350157_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350282_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350282_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350805_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350805_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350848_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12350848_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12351540_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12351540_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12351544_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12351544_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12353648_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12353648_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12354068_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12354068_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12354618_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12354618_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12355056_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12355056_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12355730_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12355730_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12355911_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12355911_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12356742_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12356742_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12357134_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12357134_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12358460_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12358460_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12358531_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12358531_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12359937_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12359937_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12360327_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12360327_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12360331_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12360331_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12360370_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12360370_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12362234_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12362234_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12363171_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12363171_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12363811_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12363811_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12384065_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12384065_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12384066_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12384066_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12385867_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12385867_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12388986_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12388986_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12390366_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12390366_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12391685_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12391685_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12392008_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12392008_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12400930_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12400930_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12400975_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12400975_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12401046_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12401046_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12401870_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12401870_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12403287_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12403287_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12412454_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12412454_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414134_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414134_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414137_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414137_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414139_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414139_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414150_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414150_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414211_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414211_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414506_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414506_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414847_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12414847_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415057_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415057_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415240_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415240_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415644_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415644_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415685_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12415685_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12416109_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12416109_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12418104_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12418104_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12421707_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12421707_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12421712_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12421712_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12421716_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12421716_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12424844_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12424844_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12425079_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12425079_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12425082_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12425082_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12425085_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12425085_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12426166_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12426166_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12426535_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12426535_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12426545_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12426545_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12429594_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12429594_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12429806_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12429806_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430046_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430046_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430767_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430767_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430789_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430789_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430943_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12430943_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12432385_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12432385_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12432492_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12432492_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437276_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437276_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437300_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437300_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437330_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437330_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437340_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437340_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437536_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437536_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437631_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437631_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437779_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12437779_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12438036_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12438036_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12440568_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12440568_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12442526_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12442526_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12444446_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12444446_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12444786_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12444786_T.xml',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12444805_T.pdf',
#  'c:\\Users\\hkpu\\Projects\\index-construction\\data-transcripts\\raw\\12444805_T.xml',
#  ...]

# %%
# processing xml
def read_xml(document, index=0):

  # creating a pdf file object
  tree = et.parse(document)
  root = tree.getroot()
  
  xmlstr = et.tostring(root, method='xml', encoding='unicode')
  if re.findall("<companyName>", xmlstr):
    # print('File is sound.')

    # add filename to dataframe
    m = re.search(r"\\(?!.*\\)(.*)((\.xml))", document)
    filename_match = m.group(0)
    filename = re.sub("[\\\/\'\>]", "", filename_match)
    filename = re.sub("\.\w+", "", filename)
    df.loc[index, 'file'] = filename
    
    print("Preprocessing metadata of", filename, "...")

    # get id
    df.loc[index, 'id'] = root[0].attrib['Id']
    
    # get company
    for company in root.findall('companyName'):
      df.loc[index, 'company'] = str(company.text)
    # get ticker
    for ticker in root.findall('companyTicker'):
      df.loc[index, 'ticker'] = str(ticker.text)
    # get date
    for date in root.findall('startDate'):
      df.loc[index, 'date'] = str(date.text)

    # get year
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df['date'].dt.year
    df['year'] = df['year'].astype(int)
  else:
    print("### ERROR ### Missing data in", document)
  
  return

# %%
# assign relative directory
directory = os.path.join(sys.path[0], path + "\\raw") ### INPUT FOLDER HERE ###

# list files in directory
files_in_dir = list_files(directory)

# count files in directory
print("Your input directory is:", directory, "\nNumber of files:", len(files_in_dir))

# initialize dataframe to hold documents
df = pd.DataFrame(columns=['file'])

# iterate over files in the directory
i = 0
for f in files_in_dir:
    if f.lower().endswith('.xml'):
        read_xml(f,i)
    i = i + 1

# df.reset_index(inplace=True, drop=True)

# Metadata from dataframe as csv
df = df[['id', 'company', 'year']]
df.columns = ['document_id', 'firm_id', 'time']
df.reset_index(drop=True, inplace=True)
df.to_csv(path + '\\input\\id2firms.csv', index=False)

with open(path + "\\input\\document_ids.txt", "w") as f_out:
    f_out.write("\n".join(df["document_id"]))

print("Done with metadata.")
# Out:
# Your input directory is: c:\Users\hkpu\Projects\index-construction\data-transcripts\raw
# Number of files: 75000
# Preprocessing metadata of 1004063_T ...
# Preprocessing metadata of 10103972_T ...
# Preprocessing metadata of 1012763_T ...
# Preprocessing metadata of 1012782_T ...
# Preprocessing metadata of 1012785_T ...
# Preprocessing metadata of 1012787_T ...
# Preprocessing metadata of 1020948_T ...
# Preprocessing metadata of 10221377_T ...
# Preprocessing metadata of 10229958_T ...
# Preprocessing metadata of 10231130_T ...
# Preprocessing metadata of 10276652_T ...
# Preprocessing metadata of 10305562_T ...
# Preprocessing metadata of 10341258_T ...
# Preprocessing metadata of 10353489_T ...
# Preprocessing metadata of 10354189_T ...
# Preprocessing metadata of 1037620_T ...
# Preprocessing metadata of 10382650_T ...
# Preprocessing metadata of 10406938_T ...
# Preprocessing metadata of 10418964_T ...
# Preprocessing metadata of 10426026_T ...
# Preprocessing metadata of 1048657_T ...
# Preprocessing metadata of 10550671_T ...
# Preprocessing metadata of 1065361_T ...
# Preprocessing metadata of 1065377_T ...
# Preprocessing metadata of 10655690_T ...
# Preprocessing metadata of 10659595_T ...
# Preprocessing metadata of 10679258_T ...
# Preprocessing metadata of 10687439_T ...
# Preprocessing metadata of 10689602_T ...
# Preprocessing metadata of 10724780_T ...
# Preprocessing metadata of 10733834_T ...
# Preprocessing metadata of 10748343_T ...
# Preprocessing metadata of 10749089_T ...
# Preprocessing metadata of 10749091_T ...
# Preprocessing metadata of 10781921_T ...
# Preprocessing metadata of 10784487_T ...
# Preprocessing metadata of 10879997_T ...
# Preprocessing metadata of 10888886_T ...
# Preprocessing metadata of 10909023_T ...
# Preprocessing metadata of 10911177_T ...
# Preprocessing metadata of 10935301_T ...
# Preprocessing metadata of 10971426_T ...
# Preprocessing metadata of 10980324_T ...
# Preprocessing metadata of 11006220_T ...
# Preprocessing metadata of 11010367_T ...
# Preprocessing metadata of 11011265_T ...
# Preprocessing metadata of 11011706_T ...
# Preprocessing metadata of 1102148_T ...
# Preprocessing metadata of 11031505_T ...
# Preprocessing metadata of 11058412_T ...
# Preprocessing metadata of 11060027_T ...
# Preprocessing metadata of 11061268_T ...
# Preprocessing metadata of 11071004_T ...
# Preprocessing metadata of 11087732_T ...
# Preprocessing metadata of 11091851_T ...
# Preprocessing metadata of 11092385_T ...
# Preprocessing metadata of 11092392_T ...
# Preprocessing metadata of 11092405_T ...
# Preprocessing metadata of 11093216_T ...
# Preprocessing metadata of 11097096_T ...
# Preprocessing metadata of 11097846_T ...
# Preprocessing metadata of 11103974_T ...
# Preprocessing metadata of 11103977_T ...
# Preprocessing metadata of 11107347_T ...
# Preprocessing metadata of 11109158_T ...
# Preprocessing metadata of 11110695_T ...
# Preprocessing metadata of 11119106_T ...
# Preprocessing metadata of 11132279_T ...
# Preprocessing metadata of 11140220_T ...
# Preprocessing metadata of 11143636_T ...
# Preprocessing metadata of 11169124_T ...
# Preprocessing metadata of 11182428_T ...
# Preprocessing metadata of 11184018_T ...
# Preprocessing metadata of 11192371_T ...
# Preprocessing metadata of 11195825_T ...
# Preprocessing metadata of 11196516_T ...
# Preprocessing metadata of 11204298_T ...
# Preprocessing metadata of 11220315_T ...
# Preprocessing metadata of 11220316_T ...
# Preprocessing metadata of 11225052_T ...
# Preprocessing metadata of 11231748_T ...
# Preprocessing metadata of 11237728_T ...
# Preprocessing metadata of 11256308_T ...
# Preprocessing metadata of 11265653_T ...
# Preprocessing metadata of 11266461_T ...
# Preprocessing metadata of 11269517_T ...
# Preprocessing metadata of 11269782_T ...
# Preprocessing metadata of 11273132_T ...
# Preprocessing metadata of 11273152_T ...
# Preprocessing metadata of 11307423_T ...
# Preprocessing metadata of 11307844_T ...
# Preprocessing metadata of 11317112_T ...
# Preprocessing metadata of 11325204_T ...
# Preprocessing metadata of 11355890_T ...
# Preprocessing metadata of 11364510_T ...
# Preprocessing metadata of 11365728_T ...
# Preprocessing metadata of 11397571_T ...
# Preprocessing metadata of 1140247_T ...
# Preprocessing metadata of 11409211_T ...
# Preprocessing metadata of 11434478_T ...
# Preprocessing metadata of 11436894_T ...
# Preprocessing metadata of 11458913_T ...
# Preprocessing metadata of 11463913_T ...
# Preprocessing metadata of 11467978_T ...
# Preprocessing metadata of 1146929_T ...
# Preprocessing metadata of 11479784_T ...
# Preprocessing metadata of 11479954_T ...
# Preprocessing metadata of 11480186_T ...
# Preprocessing metadata of 11480234_T ...
# Preprocessing metadata of 11480943_T ...
# Preprocessing metadata of 11481344_T ...
# Preprocessing metadata of 11481431_T ...
# Preprocessing metadata of 11482950_T ...
# Preprocessing metadata of 11483156_T ...
# Preprocessing metadata of 11483175_T ...
# Preprocessing metadata of 11484562_T ...
# Preprocessing metadata of 11486161_T ...
# Preprocessing metadata of 11489004_T ...
# Preprocessing metadata of 11489048_T ...
# Preprocessing metadata of 11489054_T ...
# Preprocessing metadata of 11489157_T ...
# Preprocessing metadata of 11489169_T ...
# Preprocessing metadata of 11489254_T ...
# Preprocessing metadata of 11490054_T ...
# Preprocessing metadata of 11496168_T ...
# Preprocessing metadata of 11496535_T ...
# Preprocessing metadata of 11497769_T ...
# Preprocessing metadata of 11500057_T ...
# Preprocessing metadata of 11500244_T ...
# Preprocessing metadata of 11500392_T ...
# Preprocessing metadata of 11500735_T ...
# Preprocessing metadata of 11502165_T ...
# Preprocessing metadata of 11503275_T ...
# Preprocessing metadata of 11512406_T ...
# Preprocessing metadata of 11513583_T ...
# Preprocessing metadata of 11514074_T ...
# Preprocessing metadata of 11515553_T ...
# Preprocessing metadata of 11529553_T ...
# Preprocessing metadata of 11535601_T ...
# Preprocessing metadata of 11542797_T ...
# Preprocessing metadata of 11552449_T ...
# Preprocessing metadata of 11571044_T ...
# Preprocessing metadata of 11575105_T ...
# Preprocessing metadata of 11611770_T ...
# Preprocessing metadata of 11632258_T ...
# Preprocessing metadata of 11634364_T ...
# Preprocessing metadata of 11635206_T ...
# Preprocessing metadata of 11635384_T ...
# Preprocessing metadata of 11640655_T ...
# Preprocessing metadata of 11640709_T ...
# Preprocessing metadata of 11641711_T ...
# Preprocessing metadata of 11642141_T ...
# Preprocessing metadata of 11642455_T ...
# Preprocessing metadata of 11642854_T ...
# Preprocessing metadata of 11642922_T ...
# Preprocessing metadata of 11643782_T ...
# Preprocessing metadata of 11644016_T ...
# Preprocessing metadata of 11646687_T ...
# Preprocessing metadata of 11652291_T ...
# Preprocessing metadata of 11658543_T ...
# Preprocessing metadata of 11658719_T ...
# Preprocessing metadata of 11663997_T ...
# Preprocessing metadata of 11665794_T ...
# Preprocessing metadata of 11672400_T ...
# Preprocessing metadata of 11677115_T ...
# Preprocessing metadata of 11678094_T ...
# Preprocessing metadata of 11679297_T ...
# Preprocessing metadata of 11689383_T ...
# Preprocessing metadata of 11691145_T ...
# Preprocessing metadata of 11721956_T ...
# Preprocessing metadata of 11733736_T ...
# Preprocessing metadata of 1174161_T ...
# Preprocessing metadata of 11755842_T ...
# Preprocessing metadata of 11760784_T ...
# Preprocessing metadata of 11760848_T ...
# Preprocessing metadata of 11773547_T ...
# Preprocessing metadata of 11775365_T ...
# Preprocessing metadata of 11789507_T ...
# Preprocessing metadata of 11814194_T ...
# Preprocessing metadata of 11821917_T ...
# Preprocessing metadata of 11834860_T ...
# Preprocessing metadata of 11836003_T ...
# Preprocessing metadata of 11840328_T ...
# Preprocessing metadata of 11858277_T ...
# Preprocessing metadata of 11869482_T ...
# Preprocessing metadata of 11875965_T ...
# Preprocessing metadata of 11881418_T ...
# Preprocessing metadata of 1189833_T ...
# Preprocessing metadata of 1191633_T ...
# Preprocessing metadata of 1194934_T ...
# Preprocessing metadata of 11963005_T ...
# Preprocessing metadata of 11963954_T ...
# Preprocessing metadata of 11972725_T ...
# Preprocessing metadata of 11996646_T ...
# Preprocessing metadata of 1200947_T ...
# Preprocessing metadata of 12040268_T ...
# Preprocessing metadata of 12040701_T ...
# Preprocessing metadata of 12042080_T ...
# Preprocessing metadata of 12042473_T ...
# Preprocessing metadata of 1207320_T ...
# Preprocessing metadata of 12078244_T ...
# Preprocessing metadata of 12082825_T ...
# Preprocessing metadata of 12082830_T ...
# Preprocessing metadata of 12083030_T ...
# Preprocessing metadata of 12096522_T ...
# Preprocessing metadata of 12122504_T ...
# Preprocessing metadata of 12123432_T ...
# Preprocessing metadata of 12123765_T ...
# Preprocessing metadata of 12124388_T ...
# Preprocessing metadata of 12125345_T ...
# Preprocessing metadata of 12126086_T ...
# Preprocessing metadata of 12140641_T ...
# Preprocessing metadata of 12141672_T ...
# Preprocessing metadata of 12142180_T ...
# Preprocessing metadata of 12142754_T ...
# Preprocessing metadata of 12144745_T ...
# Preprocessing metadata of 12145306_T ...
# Preprocessing metadata of 12145925_T ...
# Preprocessing metadata of 12158960_T ...
# Preprocessing metadata of 12163185_T ...
# Preprocessing metadata of 12165172_T ...
# Preprocessing metadata of 12169762_T ...
# Preprocessing metadata of 12174929_T ...
# Preprocessing metadata of 12178603_T ...
# Preprocessing metadata of 12180321_T ...
# Preprocessing metadata of 12180568_T ...
# Preprocessing metadata of 12182076_T ...
# Preprocessing metadata of 12182904_T ...
# Preprocessing metadata of 12184301_T ...
# Preprocessing metadata of 12186863_T ...
# Preprocessing metadata of 12189542_T ...
# Preprocessing metadata of 12190370_T ...
# Preprocessing metadata of 12191799_T ...
# Preprocessing metadata of 12193390_T ...
# Preprocessing metadata of 12196206_T ...
# Preprocessing metadata of 12197085_T ...
# Preprocessing metadata of 12197091_T ...
# Preprocessing metadata of 12197093_T ...
# Preprocessing metadata of 12198850_T ...
# Preprocessing metadata of 12199373_T ...
# Preprocessing metadata of 12202337_T ...
# Preprocessing metadata of 12204079_T ...
# Preprocessing metadata of 12204832_T ...
# Preprocessing metadata of 12211530_T ...
# Preprocessing metadata of 12212023_T ...
# Preprocessing metadata of 12212548_T ...
# Preprocessing metadata of 12213144_T ...
# Preprocessing metadata of 12215052_T ...
# Preprocessing metadata of 12215573_T ...
# Preprocessing metadata of 12215770_T ...
# Preprocessing metadata of 12215879_T ...
# Preprocessing metadata of 12216649_T ...
# Preprocessing metadata of 12220940_T ...
# Preprocessing metadata of 12221061_T ...
# Preprocessing metadata of 12221582_T ...
# Preprocessing metadata of 12222822_T ...
# Preprocessing metadata of 12223159_T ...
# Preprocessing metadata of 12223471_T ...
# Preprocessing metadata of 12223974_T ...
# Preprocessing metadata of 12224970_T ...
# Preprocessing metadata of 12228170_T ...
# Preprocessing metadata of 12228921_T ...
# Preprocessing metadata of 12229028_T ...
# Preprocessing metadata of 12230021_T ...
# Preprocessing metadata of 12230139_T ...
# Preprocessing metadata of 12230311_T ...
# Preprocessing metadata of 12231293_T ...
# Preprocessing metadata of 12231388_T ...
# Preprocessing metadata of 12231679_T ...
# Preprocessing metadata of 12232342_T ...
# Preprocessing metadata of 12234729_T ...
# Preprocessing metadata of 12235171_T ...
# Preprocessing metadata of 12235174_T ...
# Preprocessing metadata of 12235223_T ...
# Preprocessing metadata of 12235836_T ...
# Preprocessing metadata of 12236538_T ...
# Preprocessing metadata of 12238859_T ...
# Preprocessing metadata of 12239304_T ...
# Preprocessing metadata of 12240397_T ...
# Preprocessing metadata of 12244623_T ...
# Preprocessing metadata of 12245202_T ...
# Preprocessing metadata of 12249595_T ...
# Preprocessing metadata of 12250598_T ...
# Preprocessing metadata of 12250746_T ...
# Preprocessing metadata of 12251187_T ...
# Preprocessing metadata of 12251875_T ...
# Preprocessing metadata of 12252103_T ...
# Preprocessing metadata of 12252445_T ...
# Preprocessing metadata of 12252449_T ...
# Preprocessing metadata of 12252453_T ...
# Preprocessing metadata of 12252455_T ...
# Preprocessing metadata of 12258337_T ...
# Preprocessing metadata of 12259142_T ...
# Preprocessing metadata of 12259186_T ...
# Preprocessing metadata of 12259224_T ...
# Preprocessing metadata of 12260480_T ...
# Preprocessing metadata of 12260675_T ...
# Preprocessing metadata of 12264874_T ...
# Preprocessing metadata of 12265868_T ...
# Preprocessing metadata of 12273900_T ...
# Preprocessing metadata of 12273937_T ...
# Preprocessing metadata of 12274575_T ...
# Preprocessing metadata of 12275209_T ...
# Preprocessing metadata of 12275420_T ...
# Preprocessing metadata of 12275990_T ...
# Preprocessing metadata of 12276094_T ...
# Preprocessing metadata of 12276139_T ...
# Preprocessing metadata of 12276196_T ...
# Preprocessing metadata of 12276261_T ...
# Preprocessing metadata of 12276578_T ...
# Preprocessing metadata of 12276648_T ...
# Preprocessing metadata of 12276993_T ...
# Preprocessing metadata of 12277063_T ...
# Preprocessing metadata of 12277430_T ...
# Preprocessing metadata of 12277432_T ...
# Preprocessing metadata of 12277704_T ...
# Preprocessing metadata of 12277835_T ...
# Preprocessing metadata of 12277913_T ...
# Preprocessing metadata of 12278096_T ...
# Preprocessing metadata of 12278355_T ...
# Preprocessing metadata of 12279909_T ...
# Preprocessing metadata of 12279916_T ...
# Preprocessing metadata of 12280083_T ...
# Preprocessing metadata of 12280085_T ...
# Preprocessing metadata of 12280549_T ...
# Preprocessing metadata of 12281392_T ...
# Preprocessing metadata of 12281534_T ...
# Preprocessing metadata of 12281607_T ...
# Preprocessing metadata of 12281732_T ...
# Preprocessing metadata of 12281971_T ...
# Preprocessing metadata of 12282114_T ...
# Preprocessing metadata of 12283148_T ...
# Preprocessing metadata of 12283375_T ...
# Preprocessing metadata of 12283486_T ...
# Preprocessing metadata of 12283791_T ...
# Preprocessing metadata of 12283997_T ...
# Preprocessing metadata of 12284030_T ...
# Preprocessing metadata of 12284597_T ...
# Preprocessing metadata of 12285092_T ...
# Preprocessing metadata of 12285397_T ...
# Preprocessing metadata of 12287580_T ...
# Preprocessing metadata of 12287944_T ...
# Preprocessing metadata of 12288020_T ...
# Preprocessing metadata of 12288088_T ...
# Preprocessing metadata of 12288240_T ...
# Preprocessing metadata of 12288561_T ...
# Preprocessing metadata of 12289044_T ...
# Preprocessing metadata of 12291297_T ...
# Preprocessing metadata of 12291447_T ...
# Preprocessing metadata of 12291767_T ...
# Preprocessing metadata of 12291784_T ...
# Preprocessing metadata of 12291992_T ...
# Preprocessing metadata of 12292098_T ...
# Preprocessing metadata of 12292100_T ...
# Preprocessing metadata of 12292799_T ...
# Preprocessing metadata of 12293197_T ...
# Preprocessing metadata of 12293691_T ...
# Preprocessing metadata of 12294564_T ...
# Preprocessing metadata of 12294612_T ...
# Preprocessing metadata of 12296903_T ...
# Preprocessing metadata of 12297097_T ...
# Preprocessing metadata of 12297186_T ...
# Preprocessing metadata of 12297351_T ...
# Preprocessing metadata of 12297949_T ...
# Preprocessing metadata of 12298767_T ...
# Preprocessing metadata of 12299536_T ...
# Preprocessing metadata of 12299571_T ...
# Preprocessing metadata of 12299732_T ...
# Preprocessing metadata of 12299820_T ...
# Preprocessing metadata of 12300541_T ...
# Preprocessing metadata of 12300693_T ...
# Preprocessing metadata of 12300792_T ...
# Preprocessing metadata of 12300923_T ...
# Preprocessing metadata of 12301040_T ...
# Preprocessing metadata of 12301252_T ...
# Preprocessing metadata of 12302622_T ...
# Preprocessing metadata of 12302634_T ...
# Preprocessing metadata of 12302709_T ...
# Preprocessing metadata of 12302773_T ...
# Preprocessing metadata of 12302985_T ...
# Preprocessing metadata of 12302999_T ...
# Preprocessing metadata of 12304328_T ...
# Preprocessing metadata of 12314954_T ...
# Preprocessing metadata of 12315348_T ...
# Preprocessing metadata of 12317767_T ...
# Preprocessing metadata of 12318442_T ...
# Preprocessing metadata of 12319257_T ...
# Preprocessing metadata of 12321044_T ...
# Preprocessing metadata of 12321885_T ...
# Preprocessing metadata of 12325659_T ...
# Preprocessing metadata of 12326819_T ...
# Preprocessing metadata of 12327526_T ...
# Preprocessing metadata of 12328805_T ...
# Preprocessing metadata of 12329930_T ...
# Preprocessing metadata of 12330096_T ...
# Preprocessing metadata of 12331771_T ...
# Preprocessing metadata of 12331798_T ...
# Preprocessing metadata of 12332190_T ...
# Preprocessing metadata of 12334174_T ...
# Preprocessing metadata of 12335319_T ...
# Preprocessing metadata of 12336446_T ...
# Preprocessing metadata of 12336830_T ...
# Preprocessing metadata of 12338566_T ...
# Preprocessing metadata of 12342275_T ...
# Preprocessing metadata of 12343669_T ...
# Preprocessing metadata of 12344773_T ...
# Preprocessing metadata of 12344984_T ...
# Preprocessing metadata of 12345087_T ...
# Preprocessing metadata of 12345498_T ...
# Preprocessing metadata of 12347162_T ...
# Preprocessing metadata of 12348318_T ...
# Preprocessing metadata of 12348334_T ...
# Preprocessing metadata of 12348343_T ...
# Preprocessing metadata of 12348348_T ...
# Preprocessing metadata of 12348544_T ...
# Preprocessing metadata of 12349329_T ...
# Preprocessing metadata of 12349721_T ...
# Preprocessing metadata of 12349827_T ...
# Preprocessing metadata of 12349885_T ...
# Preprocessing metadata of 12350134_T ...
# Preprocessing metadata of 12350157_T ...
# Preprocessing metadata of 12350282_T ...
# Preprocessing metadata of 12350805_T ...
# Preprocessing metadata of 12350848_T ...
# Preprocessing metadata of 12351540_T ...
# Preprocessing metadata of 12351544_T ...
# Preprocessing metadata of 12353648_T ...
# Preprocessing metadata of 12354068_T ...
# Preprocessing metadata of 12354618_T ...
# Preprocessing metadata of 12355056_T ...
# Preprocessing metadata of 12355730_T ...
# Preprocessing metadata of 12355911_T ...
# Preprocessing metadata of 12356742_T ...
# Preprocessing metadata of 12357134_T ...
# Preprocessing metadata of 12358460_T ...
# Preprocessing metadata of 12358531_T ...
# Preprocessing metadata of 12359937_T ...
# Preprocessing metadata of 12360327_T ...
# Preprocessing metadata of 12360331_T ...
# Preprocessing metadata of 12360370_T ...
# Preprocessing metadata of 12362234_T ...
# Preprocessing metadata of 12363171_T ...
# Preprocessing metadata of 12363811_T ...
# Preprocessing metadata of 12384065_T ...
# Preprocessing metadata of 12384066_T ...
# Preprocessing metadata of 12385867_T ...
# Preprocessing metadata of 12388986_T ...
# Preprocessing metadata of 12390366_T ...
# Preprocessing metadata of 12391685_T ...
# Preprocessing metadata of 12392008_T ...
# Preprocessing metadata of 12400930_T ...
# Preprocessing metadata of 12400975_T ...
# Preprocessing metadata of 12401046_T ...
# Preprocessing metadata of 12401870_T ...
# Preprocessing metadata of 12403287_T ...
# Preprocessing metadata of 12412454_T ...
# Preprocessing metadata of 12414134_T ...
# Preprocessing metadata of 12414137_T ...
# Preprocessing metadata of 12414139_T ...
# Preprocessing metadata of 12414150_T ...
# Preprocessing metadata of 12414211_T ...
# Preprocessing metadata of 12414506_T ...
# Preprocessing metadata of 12414847_T ...
# Preprocessing metadata of 12415057_T ...
# Preprocessing metadata of 12415240_T ...
# Preprocessing metadata of 12415644_T ...
# Preprocessing metadata of 12415685_T ...
# Preprocessing metadata of 12416109_T ...
# Preprocessing metadata of 12418104_T ...
# Preprocessing metadata of 12421707_T ...
# Preprocessing metadata of 12421712_T ...
# Preprocessing metadata of 12421716_T ...
# Preprocessing metadata of 12424844_T ...
# Preprocessing metadata of 12425079_T ...
# Preprocessing metadata of 12425082_T ...
# Preprocessing metadata of 12425085_T ...
# Preprocessing metadata of 12426166_T ...
# Preprocessing metadata of 12426535_T ...
# Preprocessing metadata of 12426545_T ...
# Preprocessing metadata of 12429594_T ...
# Preprocessing metadata of 12429806_T ...
# Preprocessing metadata of 12430046_T ...
# Preprocessing metadata of 12430767_T ...
# Preprocessing metadata of 12430789_T ...
# Preprocessing metadata of 12430943_T ...
# Preprocessing metadata of 12432385_T ...
# Preprocessing metadata of 12432492_T ...
# Preprocessing metadata of 12437276_T ...
# Preprocessing metadata of 12437300_T ...
# Preprocessing metadata of 12437330_T ...
# Preprocessing metadata of 12437340_T ...
# Preprocessing metadata of 12437536_T ...
# Preprocessing metadata of 12437631_T ...
# Preprocessing metadata of 12437779_T ...
# Preprocessing metadata of 12438036_T ...
# Preprocessing metadata of 12440568_T ...
# Preprocessing metadata of 12442526_T ...
# Preprocessing metadata of 12444446_T ...
# Preprocessing metadata of 12444786_T ...
# Preprocessing metadata of 12444805_T ...
# Preprocessing metadata of 12446211_T ...
# Preprocessing metadata of 12446592_T ...
# Preprocessing metadata of 12446833_T ...
# Preprocessing metadata of 12447471_T ...
# Preprocessing metadata of 12452172_T ...
# Preprocessing metadata of 12454060_T ...
# Preprocessing metadata of 12454259_T ...
# Preprocessing metadata of 12454333_T ...
# Preprocessing metadata of 12454678_T ...
# Preprocessing metadata of 12454837_T ...
# Preprocessing metadata of 12455032_T ...
# Preprocessing metadata of 12456481_T ...
# Preprocessing metadata of 12457689_T ...
# Preprocessing metadata of 12457858_T ...
# Preprocessing metadata of 12458673_T ...
# Preprocessing metadata of 12458676_T ...
# Preprocessing metadata of 12458725_T ...
# Preprocessing metadata of 12460591_T ...
# Preprocessing metadata of 12460593_T ...
# Preprocessing metadata of 12460598_T ...
# Preprocessing metadata of 12460601_T ...
# Preprocessing metadata of 12465014_T ...
# Preprocessing metadata of 12466612_T ...
# Preprocessing metadata of 12467502_T ...
# Preprocessing metadata of 12467845_T ...
# Preprocessing metadata of 12468139_T ...
# Preprocessing metadata of 12469239_T ...
# Preprocessing metadata of 12469673_T ...
# Preprocessing metadata of 12469743_T ...
# Preprocessing metadata of 12469772_T ...
# Preprocessing metadata of 12470083_T ...
# Preprocessing metadata of 12472281_T ...
# Preprocessing metadata of 12472545_T ...
# Preprocessing metadata of 12473878_T ...
# Preprocessing metadata of 12475023_T ...
# Preprocessing metadata of 12477707_T ...
# Preprocessing metadata of 12478432_T ...
# Preprocessing metadata of 12483410_T ...
# Preprocessing metadata of 12483548_T ...
# Preprocessing metadata of 12483561_T ...
# Preprocessing metadata of 12483651_T ...
# Preprocessing metadata of 12484185_T ...
# Preprocessing metadata of 12486774_T ...
# Preprocessing metadata of 12487540_T ...
# Preprocessing metadata of 12488244_T ...
# Preprocessing metadata of 12488406_T ...
# Preprocessing metadata of 12490564_T ...
# Preprocessing metadata of 12490582_T ...
# Preprocessing metadata of 12490659_T ...
# Preprocessing metadata of 12491301_T ...
# Preprocessing metadata of 12493427_T ...
# Preprocessing metadata of 12493857_T ...
# Preprocessing metadata of 12493862_T ...
# Preprocessing metadata of 12493961_T ...
# Preprocessing metadata of 12494204_T ...
# Preprocessing metadata of 12494616_T ...
# Preprocessing metadata of 12495005_T ...
# Preprocessing metadata of 12495277_T ...
# Preprocessing metadata of 12495553_T ...
# Preprocessing metadata of 12495651_T ...
# Preprocessing metadata of 12495679_T ...
# Preprocessing metadata of 12495707_T ...
# Preprocessing metadata of 12495879_T ...
# Preprocessing metadata of 12496397_T ...
# Preprocessing metadata of 12497382_T ...
# Preprocessing metadata of 12497822_T ...
# Preprocessing metadata of 12497889_T ...
# Preprocessing metadata of 12498057_T ...
# Preprocessing metadata of 12498291_T ...
# Preprocessing metadata of 12499450_T ...
# Preprocessing metadata of 12499722_T ...
# Preprocessing metadata of 12500199_T ...
# Preprocessing metadata of 12500286_T ...
# Preprocessing metadata of 12501050_T ...
# Preprocessing metadata of 12501533_T ...
# Preprocessing metadata of 12501830_T ...
# Preprocessing metadata of 12504676_T ...
# Preprocessing metadata of 12504855_T ...
# Preprocessing metadata of 12505468_T ...
# Preprocessing metadata of 12506230_T ...
# Preprocessing metadata of 12509923_T ...
# Preprocessing metadata of 12511050_T ...
# Preprocessing metadata of 12512875_T ...
# Preprocessing metadata of 12514072_T ...
# Preprocessing metadata of 12514074_T ...
# Preprocessing metadata of 12517637_T ...
# Preprocessing metadata of 12517640_T ...
# Preprocessing metadata of 12517643_T ...
# Preprocessing metadata of 12517646_T ...
# Preprocessing metadata of 12517652_T ...
# Preprocessing metadata of 12518429_T ...
# Preprocessing metadata of 12518891_T ...
# Preprocessing metadata of 12518895_T ...
# Preprocessing metadata of 12521688_T ...
# Preprocessing metadata of 12522578_T ...
# Preprocessing metadata of 12528406_T ...
# Preprocessing metadata of 12528700_T ...
# Preprocessing metadata of 12529143_T ...
# Preprocessing metadata of 12530113_T ...
# Preprocessing metadata of 12530144_T ...
# Preprocessing metadata of 12530169_T ...
# Preprocessing metadata of 12530207_T ...
# Preprocessing metadata of 12530304_T ...
# Preprocessing metadata of 12530326_T ...
# Preprocessing metadata of 12531046_T ...
# Preprocessing metadata of 12531275_T ...
# Preprocessing metadata of 12533742_T ...
# Preprocessing metadata of 12534946_T ...
# Preprocessing metadata of 12534999_T ...
# Preprocessing metadata of 12535092_T ...
# Preprocessing metadata of 12535253_T ...
# Preprocessing metadata of 12535254_T ...
# Preprocessing metadata of 12535661_T ...
# Preprocessing metadata of 12535698_T ...
# Preprocessing metadata of 12535782_T ...
# Preprocessing metadata of 12537582_T ...
# Preprocessing metadata of 12538650_T ...
# Preprocessing metadata of 12540295_T ...
# Preprocessing metadata of 12540461_T ...
# Preprocessing metadata of 12541236_T ...
# Preprocessing metadata of 12542966_T ...
# Preprocessing metadata of 12543256_T ...
# Preprocessing metadata of 12543489_T ...
# Preprocessing metadata of 12543667_T ...
# Preprocessing metadata of 12545364_T ...
# Preprocessing metadata of 12548150_T ...
# Preprocessing metadata of 12548239_T ...
# Preprocessing metadata of 12548410_T ...
# Preprocessing metadata of 12548627_T ...
# Preprocessing metadata of 12549313_T ...
# Preprocessing metadata of 12549932_T ...
# Preprocessing metadata of 12549940_T ...
# Preprocessing metadata of 12549943_T ...
# Preprocessing metadata of 12549947_T ...
# Preprocessing metadata of 12549949_T ...
# Preprocessing metadata of 12550039_T ...
# Preprocessing metadata of 12550096_T ...
# Preprocessing metadata of 12550483_T ...
# Preprocessing metadata of 12550485_T ...
# Preprocessing metadata of 12550699_T ...
# Preprocessing metadata of 12550746_T ...
# Preprocessing metadata of 12550820_T ...
# Preprocessing metadata of 12550823_T ...
# Preprocessing metadata of 12550829_T ...
# Preprocessing metadata of 12550837_T ...
# Preprocessing metadata of 12550921_T ...
# Preprocessing metadata of 12553559_T ...
# Preprocessing metadata of 12554137_T ...
# Preprocessing metadata of 12555091_T ...
# Preprocessing metadata of 12555106_T ...
# Preprocessing metadata of 12555828_T ...
# Preprocessing metadata of 12555837_T ...
# Preprocessing metadata of 12555870_T ...
# Preprocessing metadata of 12555899_T ...
# Preprocessing metadata of 12555967_T ...
# Preprocessing metadata of 12555968_T ...
# Preprocessing metadata of 12556383_T ...
# Preprocessing metadata of 12557003_T ...
# Preprocessing metadata of 12557044_T ...
# Preprocessing metadata of 12557078_T ...
# Preprocessing metadata of 12557130_T ...
# Preprocessing metadata of 12558101_T ...
# Preprocessing metadata of 12558103_T ...
# Preprocessing metadata of 12558374_T ...
# Preprocessing metadata of 12558443_T ...
# Preprocessing metadata of 12558940_T ...
# Preprocessing metadata of 12559096_T ...
# Preprocessing metadata of 12559554_T ...
# Preprocessing metadata of 12559700_T ...
# Preprocessing metadata of 12559702_T ...
# Preprocessing metadata of 12559704_T ...
# Preprocessing metadata of 12560100_T ...
# Preprocessing metadata of 12560102_T ...
# Preprocessing metadata of 12560105_T ...
# Preprocessing metadata of 12560107_T ...
# Preprocessing metadata of 12560536_T ...
# Preprocessing metadata of 12563928_T ...
# Preprocessing metadata of 12564330_T ...
# Preprocessing metadata of 12564722_T ...
# Preprocessing metadata of 12564868_T ...
# Preprocessing metadata of 12564869_T ...
# Preprocessing metadata of 12565452_T ...
# Preprocessing metadata of 12565536_T ...
# Preprocessing metadata of 12565921_T ...
# Preprocessing metadata of 12565925_T ...
# Preprocessing metadata of 12566575_T ...
# Preprocessing metadata of 12567706_T ...
# Preprocessing metadata of 12568163_T ...
# Preprocessing metadata of 12568171_T ...
# Preprocessing metadata of 12568176_T ...
# Preprocessing metadata of 12568781_T ...
# Preprocessing metadata of 12569800_T ...
# Preprocessing metadata of 12569810_T ...
# Preprocessing metadata of 12569812_T ...
# Preprocessing metadata of 12569821_T ...
# Preprocessing metadata of 12570160_T ...
# Preprocessing metadata of 12573698_T ...
# Preprocessing metadata of 12574327_T ...
# Preprocessing metadata of 12574329_T ...
# Preprocessing metadata of 12574333_T ...
# Preprocessing metadata of 12574343_T ...
# Preprocessing metadata of 12575326_T ...
# Preprocessing metadata of 12575328_T ...
# Preprocessing metadata of 12575330_T ...
# Preprocessing metadata of 12575332_T ...
# Preprocessing metadata of 12575844_T ...
# Preprocessing metadata of 12578251_T ...
# Preprocessing metadata of 12578252_T ...
# Preprocessing metadata of 12578255_T ...
# Preprocessing metadata of 12578256_T ...
# Preprocessing metadata of 12578957_T ...
# Preprocessing metadata of 12578976_T ...
# Preprocessing metadata of 12580073_T ...
# Preprocessing metadata of 12580074_T ...
# Preprocessing metadata of 12580482_T ...
# Preprocessing metadata of 12580520_T ...
# Preprocessing metadata of 12583236_T ...
# Preprocessing metadata of 12585252_T ...
# Preprocessing metadata of 12585859_T ...
# Preprocessing metadata of 12587705_T ...
# Preprocessing metadata of 12588504_T ...
# Preprocessing metadata of 12593126_T ...
# Preprocessing metadata of 12593128_T ...
# Preprocessing metadata of 12593130_T ...
# Preprocessing metadata of 12593133_T ...
# Preprocessing metadata of 12597120_T ...
# Preprocessing metadata of 12597317_T ...
# Preprocessing metadata of 12597320_T ...
# Preprocessing metadata of 12597443_T ...
# Preprocessing metadata of 12597989_T ...
# Preprocessing metadata of 12599901_T ...
# Preprocessing metadata of 12600022_T ...
# Preprocessing metadata of 12600033_T ...
# Preprocessing metadata of 12600904_T ...
# Preprocessing metadata of 12602697_T ...
# Preprocessing metadata of 12602766_T ...
# Preprocessing metadata of 12603080_T ...
# Preprocessing metadata of 12603190_T ...
# Preprocessing metadata of 12603195_T ...
# Preprocessing metadata of 12603202_T ...
# Preprocessing metadata of 12603205_T ...
# Preprocessing metadata of 12603368_T ...
# Preprocessing metadata of 12603369_T ...
# Preprocessing metadata of 12603370_T ...
# Preprocessing metadata of 12604303_T ...
# Preprocessing metadata of 12606506_T ...
# Preprocessing metadata of 12606877_T ...
# Preprocessing metadata of 12606997_T ...
# Preprocessing metadata of 12606998_T ...
# Preprocessing metadata of 12607001_T ...
# Preprocessing metadata of 12607055_T ...
# Preprocessing metadata of 12607432_T ...
# Preprocessing metadata of 12607518_T ...
# Preprocessing metadata of 12607552_T ...
# Preprocessing metadata of 12607622_T ...
# Preprocessing metadata of 12607716_T ...
# Preprocessing metadata of 12607718_T ...
# Preprocessing metadata of 12607879_T ...
# Preprocessing metadata of 12608155_T ...
# Preprocessing metadata of 12608180_T ...
# Preprocessing metadata of 12608184_T ...
# Preprocessing metadata of 12608602_T ...
# Preprocessing metadata of 12608776_T ...
# Preprocessing metadata of 12608876_T ...
# Preprocessing metadata of 12608950_T ...
# Preprocessing metadata of 12609170_T ...
# Preprocessing metadata of 12611620_T ...
# Preprocessing metadata of 12611679_T ...
# Preprocessing metadata of 12611743_T ...
# Preprocessing metadata of 12611900_T ...
# Preprocessing metadata of 12612199_T ...
# Preprocessing metadata of 12612697_T ...
# Preprocessing metadata of 12613370_T ...
# Preprocessing metadata of 12613483_T ...
# Preprocessing metadata of 12613485_T ...
# Preprocessing metadata of 12613487_T ...
# Preprocessing metadata of 12613512_T ...
# Preprocessing metadata of 12613987_T ...
# Preprocessing metadata of 12614636_T ...
# Preprocessing metadata of 12614796_T ...
# Preprocessing metadata of 12614855_T ...
# Preprocessing metadata of 12615015_T ...
# Preprocessing metadata of 12615020_T ...
# Preprocessing metadata of 12615029_T ...
# Preprocessing metadata of 12615030_T ...
# Preprocessing metadata of 12615128_T ...
# Preprocessing metadata of 12615259_T ...
# Preprocessing metadata of 12615260_T ...
# Preprocessing metadata of 12615790_T ...
# Preprocessing metadata of 12616227_T ...
# Preprocessing metadata of 12617310_T ...
# Preprocessing metadata of 12619597_T ...
# Preprocessing metadata of 12619973_T ...
# Preprocessing metadata of 12620328_T ...
# Preprocessing metadata of 12620490_T ...
# Preprocessing metadata of 12621086_T ...
# Preprocessing metadata of 12621132_T ...
# Preprocessing metadata of 12621435_T ...
# Preprocessing metadata of 12623241_T ...
# Preprocessing metadata of 12623662_T ...
# Preprocessing metadata of 12623685_T ...
# Preprocessing metadata of 12625604_T ...
# Preprocessing metadata of 12625854_T ...
# Preprocessing metadata of 12626958_T ...
# Preprocessing metadata of 12627190_T ...
# Preprocessing metadata of 12627416_T ...
# Preprocessing metadata of 12627627_T ...
# Preprocessing metadata of 12627739_T ...
# Preprocessing metadata of 12628287_T ...
# Preprocessing metadata of 12628295_T ...
# Preprocessing metadata of 12628681_T ...
# Preprocessing metadata of 12629509_T ...
# Preprocessing metadata of 12629580_T ...
# Preprocessing metadata of 12630002_T ...
# Preprocessing metadata of 12630006_T ...
# Preprocessing metadata of 12630008_T ...
# Preprocessing metadata of 12630015_T ...
# Preprocessing metadata of 12630101_T ...
# Preprocessing metadata of 12630132_T ...
# Preprocessing metadata of 12630158_T ...
# Preprocessing metadata of 12630451_T ...
# Preprocessing metadata of 12630565_T ...
# Preprocessing metadata of 12630576_T ...
# Preprocessing metadata of 12630597_T ...
# Preprocessing metadata of 12630599_T ...
# Preprocessing metadata of 12630604_T ...
# Preprocessing metadata of 12630605_T ...
# Preprocessing metadata of 12630891_T ...
# Preprocessing metadata of 12630898_T ...
# Preprocessing metadata of 12630903_T ...
# Preprocessing metadata of 12630906_T ...
# Preprocessing metadata of 12630921_T ...
# Preprocessing metadata of 12630924_T ...
# Preprocessing metadata of 12631037_T ...
# Preprocessing metadata of 12631110_T ...
# Preprocessing metadata of 12631112_T ...
# Preprocessing metadata of 12632062_T ...
# Preprocessing metadata of 12632064_T ...
# Preprocessing metadata of 12632066_T ...
# Preprocessing metadata of 12632359_T ...
# Preprocessing metadata of 12632603_T ...
# Preprocessing metadata of 12632607_T ...
# Preprocessing metadata of 12632696_T ...
# Preprocessing metadata of 12632966_T ...
# Preprocessing metadata of 12633017_T ...
# Preprocessing metadata of 12634643_T ...
# Preprocessing metadata of 12635511_T ...
# Preprocessing metadata of 12635657_T ...
# Preprocessing metadata of 12636848_T ...
# Preprocessing metadata of 12636980_T ...
# Preprocessing metadata of 12638307_T ...
# Preprocessing metadata of 12638325_T ...
# Preprocessing metadata of 12638327_T ...
# Preprocessing metadata of 12638330_T ...
# Preprocessing metadata of 12638331_T ...
# Preprocessing metadata of 12638945_T ...
# Preprocessing metadata of 12640503_T ...
# Preprocessing metadata of 12641353_T ...
# Preprocessing metadata of 12641825_T ...
# Preprocessing metadata of 12644147_T ...
# Preprocessing metadata of 12644396_T ...
# Preprocessing metadata of 12645039_T ...
# Preprocessing metadata of 12645601_T ...
# Preprocessing metadata of 12645685_T ...
# Preprocessing metadata of 12645700_T ...
# Preprocessing metadata of 12645818_T ...
# Preprocessing metadata of 12646987_T ...
# Preprocessing metadata of 12646989_T ...
# Preprocessing metadata of 12647476_T ...
# Preprocessing metadata of 12647703_T ...
# Preprocessing metadata of 12648806_T ...
# Preprocessing metadata of 12648992_T ...
# Preprocessing metadata of 12649010_T ...
# Preprocessing metadata of 12649541_T ...
# Preprocessing metadata of 12650545_T ...
# Preprocessing metadata of 12652680_T ...
# Preprocessing metadata of 12654697_T ...
# Preprocessing metadata of 12657026_T ...
# Preprocessing metadata of 12658196_T ...
# Preprocessing metadata of 12667715_T ...
# Preprocessing metadata of 12668241_T ...
# Preprocessing metadata of 12668249_T ...
# Preprocessing metadata of 12668410_T ...
# Preprocessing metadata of 12669541_T ...
# Preprocessing metadata of 12670282_T ...
# Preprocessing metadata of 12670288_T ...
# Preprocessing metadata of 12670353_T ...
# Preprocessing metadata of 12672250_T ...
# Preprocessing metadata of 12672278_T ...
# Preprocessing metadata of 12672901_T ...
# Preprocessing metadata of 12672907_T ...
# Preprocessing metadata of 12674160_T ...
# Preprocessing metadata of 12674285_T ...
# Preprocessing metadata of 12674391_T ...
# Preprocessing metadata of 12674679_T ...
# Preprocessing metadata of 12674875_T ...
# Preprocessing metadata of 12675057_T ...
# Preprocessing metadata of 12675193_T ...
# Preprocessing metadata of 12675209_T ...
# Preprocessing metadata of 12675241_T ...
# Preprocessing metadata of 12675365_T ...
# Preprocessing metadata of 12675892_T ...
# Preprocessing metadata of 12676568_T ...
# Preprocessing metadata of 12676806_T ...
# Preprocessing metadata of 12676807_T ...
# Preprocessing metadata of 12676810_T ...
# Preprocessing metadata of 12676814_T ...
# Preprocessing metadata of 12677055_T ...
# Preprocessing metadata of 12677210_T ...
# Preprocessing metadata of 12678165_T ...
# Preprocessing metadata of 12678560_T ...
# Preprocessing metadata of 12679020_T ...
# Preprocessing metadata of 12679521_T ...
# Preprocessing metadata of 12679675_T ...
# Preprocessing metadata of 12679677_T ...
# Preprocessing metadata of 12679687_T ...
# Preprocessing metadata of 12679781_T ...
# Preprocessing metadata of 12682377_T ...
# Preprocessing metadata of 12682739_T ...
# Preprocessing metadata of 12683059_T ...
# Preprocessing metadata of 12683101_T ...
# Preprocessing metadata of 12683286_T ...
# Preprocessing metadata of 12683357_T ...
# Preprocessing metadata of 12683358_T ...
# Preprocessing metadata of 12683369_T ...
# Preprocessing metadata of 12683408_T ...
# Preprocessing metadata of 12683422_T ...
# Preprocessing metadata of 12683424_T ...
# Preprocessing metadata of 12683425_T ...
# Preprocessing metadata of 12683450_T ...
# Preprocessing metadata of 12683458_T ...
# Preprocessing metadata of 12683459_T ...
# Preprocessing metadata of 12683687_T ...
# Preprocessing metadata of 12683695_T ...
# Preprocessing metadata of 12683772_T ...
# Preprocessing metadata of 12683953_T ...
# Preprocessing metadata of 12684034_T ...
# Preprocessing metadata of 12684042_T ...
# Preprocessing metadata of 12684057_T ...
# Preprocessing metadata of 12684067_T ...
# Preprocessing metadata of 12691020_T ...
# Preprocessing metadata of 12694961_T ...
# Preprocessing metadata of 12694980_T ...
# Preprocessing metadata of 12695511_T ...
# Preprocessing metadata of 12695532_T ...
# Preprocessing metadata of 12695592_T ...
# Preprocessing metadata of 12696131_T ...
# Preprocessing metadata of 12696132_T ...
# Preprocessing metadata of 12696133_T ...
# Preprocessing metadata of 12697737_T ...
# Preprocessing metadata of 12698117_T ...
# Preprocessing metadata of 12698517_T ...
# Preprocessing metadata of 12698524_T ...
# Preprocessing metadata of 12698527_T ...
# Preprocessing metadata of 12701838_T ...
# Preprocessing metadata of 12701871_T ...
# Preprocessing metadata of 12701873_T ...
# Preprocessing metadata of 12701874_T ...
# Preprocessing metadata of 12701876_T ...
# Preprocessing metadata of 12702111_T ...
# Preprocessing metadata of 12702502_T ...
# Preprocessing metadata of 12702602_T ...
# Preprocessing metadata of 12702635_T ...
# Preprocessing metadata of 12702890_T ...
# Preprocessing metadata of 12702958_T ...
# Preprocessing metadata of 12704063_T ...
# Preprocessing metadata of 12704146_T ...
# Preprocessing metadata of 12704175_T ...
# Preprocessing metadata of 12704210_T ...
# Preprocessing metadata of 12704211_T ...
# Preprocessing metadata of 12704212_T ...
# Preprocessing metadata of 12704215_T ...
# Preprocessing metadata of 12704485_T ...
# Preprocessing metadata of 12706801_T ...
# Preprocessing metadata of 12706996_T ...
# Preprocessing metadata of 12707440_T ...
# Preprocessing metadata of 12707441_T ...
# Preprocessing metadata of 12707442_T ...
# Preprocessing metadata of 12707445_T ...
# Preprocessing metadata of 12707460_T ...
# Preprocessing metadata of 12707766_T ...
# Preprocessing metadata of 12708022_T ...
# Preprocessing metadata of 12708024_T ...
# Preprocessing metadata of 12708027_T ...
# Preprocessing metadata of 12708189_T ...
# Preprocessing metadata of 12708259_T ...
# Preprocessing metadata of 12709941_T ...
# Preprocessing metadata of 12710045_T ...
# Preprocessing metadata of 12710103_T ...
# Preprocessing metadata of 12710473_T ...
# Preprocessing metadata of 12710873_T ...
# Preprocessing metadata of 12710882_T ...
# Preprocessing metadata of 12710883_T ...
# Preprocessing metadata of 12711015_T ...
# Preprocessing metadata of 12711016_T ...
# Preprocessing metadata of 12711017_T ...
# Preprocessing metadata of 12711020_T ...
# Preprocessing metadata of 12711037_T ...
# Preprocessing metadata of 12711114_T ...
# Preprocessing metadata of 12711921_T ...
# Preprocessing metadata of 12711946_T ...
# Preprocessing metadata of 12712030_T ...
# Preprocessing metadata of 12712162_T ...
# Preprocessing metadata of 12712482_T ...
# Preprocessing metadata of 12712508_T ...
# Preprocessing metadata of 12712761_T ...
# Preprocessing metadata of 12712865_T ...
# Preprocessing metadata of 12712871_T ...
# Preprocessing metadata of 12712934_T ...
# Preprocessing metadata of 12713187_T ...
# Preprocessing metadata of 12713387_T ...
# Preprocessing metadata of 12713481_T ...
# Preprocessing metadata of 12714485_T ...
# Preprocessing metadata of 12714488_T ...
# Preprocessing metadata of 12714640_T ...
# Preprocessing metadata of 12715197_T ...
# Preprocessing metadata of 12715266_T ...
# Preprocessing metadata of 12715267_T ...
# Preprocessing metadata of 12715271_T ...
# Preprocessing metadata of 12715274_T ...
# Preprocessing metadata of 12717229_T ...
# Preprocessing metadata of 12717740_T ...
# Preprocessing metadata of 12717745_T ...
# Preprocessing metadata of 12717748_T ...
# Preprocessing metadata of 12717750_T ...
# Preprocessing metadata of 12717779_T ...
# Preprocessing metadata of 12717876_T ...
# Preprocessing metadata of 12717877_T ...
# Preprocessing metadata of 12717879_T ...
# Preprocessing metadata of 12717886_T ...
# Preprocessing metadata of 12717938_T ...
# Preprocessing metadata of 12719058_T ...
# Preprocessing metadata of 12719104_T ...
# Preprocessing metadata of 12719218_T ...
# Preprocessing metadata of 12719232_T ...
# Preprocessing metadata of 12719425_T ...
# Preprocessing metadata of 12719531_T ...
# Preprocessing metadata of 12719533_T ...
# Preprocessing metadata of 12719566_T ...
# Preprocessing metadata of 12719814_T ...
# Preprocessing metadata of 12720018_T ...
# Preprocessing metadata of 12720587_T ...
# Preprocessing metadata of 12721168_T ...
# Preprocessing metadata of 12721169_T ...
# Preprocessing metadata of 12721170_T ...
# Preprocessing metadata of 12721172_T ...
# Preprocessing metadata of 12721189_T ...
# Preprocessing metadata of 12721190_T ...
# Preprocessing metadata of 12721200_T ...
# Preprocessing metadata of 12724554_T ...
# Preprocessing metadata of 12724916_T ...
# Preprocessing metadata of 12724918_T ...
# Preprocessing metadata of 12724932_T ...
# Preprocessing metadata of 12725162_T ...
# Preprocessing metadata of 12725184_T ...
# Preprocessing metadata of 12725292_T ...
# Preprocessing metadata of 12725311_T ...
# Preprocessing metadata of 12726288_T ...
# Preprocessing metadata of 12726476_T ...
# Preprocessing metadata of 12726478_T ...
# Preprocessing metadata of 12726486_T ...
# Preprocessing metadata of 12726487_T ...
# Preprocessing metadata of 12726528_T ...
# Preprocessing metadata of 12726758_T ...
# Preprocessing metadata of 12726761_T ...
# Preprocessing metadata of 12726955_T ...
# Preprocessing metadata of 12727119_T ...
# Preprocessing metadata of 12727306_T ...
# Preprocessing metadata of 12727379_T ...
# Preprocessing metadata of 12727420_T ...
# Preprocessing metadata of 12727658_T ...
# Preprocessing metadata of 12728104_T ...
# Preprocessing metadata of 12728106_T ...
# Preprocessing metadata of 12728109_T ...
# Preprocessing metadata of 12728111_T ...
# Preprocessing metadata of 12728116_T ...
# Preprocessing metadata of 12728122_T ...
# Preprocessing metadata of 12728125_T ...
# Preprocessing metadata of 12728126_T ...
# Preprocessing metadata of 12728129_T ...
# Preprocessing metadata of 12728210_T ...
# Preprocessing metadata of 12728562_T ...
# Preprocessing metadata of 12728845_T ...
# Preprocessing metadata of 12733520_T ...
# Preprocessing metadata of 12733723_T ...
# Preprocessing metadata of 12733844_T ...
# Preprocessing metadata of 12734115_T ...
# Preprocessing metadata of 12734382_T ...
# Preprocessing metadata of 12734383_T ...
# Preprocessing metadata of 12734387_T ...
# Preprocessing metadata of 12734397_T ...
# Preprocessing metadata of 12734796_T ...
# Preprocessing metadata of 12734805_T ...
# Preprocessing metadata of 12734809_T ...
# Preprocessing metadata of 12734813_T ...
# Preprocessing metadata of 12735308_T ...
# Preprocessing metadata of 12735309_T ...
# Preprocessing metadata of 12735310_T ...
# Preprocessing metadata of 12735312_T ...
# Preprocessing metadata of 12735491_T ...
# Preprocessing metadata of 12735493_T ...
# Preprocessing metadata of 12735495_T ...
# Preprocessing metadata of 12735812_T ...
# Preprocessing metadata of 12735814_T ...
# Preprocessing metadata of 12736110_T ...
# Preprocessing metadata of 12736113_T ...
# Preprocessing metadata of 12736117_T ...
# Preprocessing metadata of 12736118_T ...
# Preprocessing metadata of 12736122_T ...
# Preprocessing metadata of 12736357_T ...
# Preprocessing metadata of 12736384_T ...
# Preprocessing metadata of 12736839_T ...
# Preprocessing metadata of 12736899_T ...
# Preprocessing metadata of 12736951_T ...
# Preprocessing metadata of 12739708_T ...
# Preprocessing metadata of 12739938_T ...
# Preprocessing metadata of 12740315_T ...
# Preprocessing metadata of 12740331_T ...
# Preprocessing metadata of 12740340_T ...
# Preprocessing metadata of 12740358_T ...
# Preprocessing metadata of 12740397_T ...
# Preprocessing metadata of 12741616_T ...
# Preprocessing metadata of 12741623_T ...
# Preprocessing metadata of 12741630_T ...
# Preprocessing metadata of 12741633_T ...
# Preprocessing metadata of 12741932_T ...
# Preprocessing metadata of 12742061_T ...
# Preprocessing metadata of 12742434_T ...
# Preprocessing metadata of 12742487_T ...
# Preprocessing metadata of 12742488_T ...
# Preprocessing metadata of 12742492_T ...
# Preprocessing metadata of 12742495_T ...
# Preprocessing metadata of 12746671_T ...
# Preprocessing metadata of 12748716_T ...
# Preprocessing metadata of 12749651_T ...
# Preprocessing metadata of 12749753_T ...
# Preprocessing metadata of 12750164_T ...
# Preprocessing metadata of 12750181_T ...
# Preprocessing metadata of 12750182_T ...
# Preprocessing metadata of 12750184_T ...
# Preprocessing metadata of 12750416_T ...
# Preprocessing metadata of 12750860_T ...
# Preprocessing metadata of 12750962_T ...
# Preprocessing metadata of 12751131_T ...
# Preprocessing metadata of 12751133_T ...
# Preprocessing metadata of 12751134_T ...
# Preprocessing metadata of 12751135_T ...
# Preprocessing metadata of 12751229_T ...
# Preprocessing metadata of 12751336_T ...
# Preprocessing metadata of 12751385_T ...
# Preprocessing metadata of 12751813_T ...
# Preprocessing metadata of 12752680_T ...
# Preprocessing metadata of 12753057_T ...
# Preprocessing metadata of 12753066_T ...
# Preprocessing metadata of 12753089_T ...
# Preprocessing metadata of 12753135_T ...
# Preprocessing metadata of 12759275_T ...
# Preprocessing metadata of 12759438_T ...
# Preprocessing metadata of 12759440_T ...
# Preprocessing metadata of 12759446_T ...
# Preprocessing metadata of 12759450_T ...
# Preprocessing metadata of 12759455_T ...
# Preprocessing metadata of 12764077_T ...
# Preprocessing metadata of 12764100_T ...
# Preprocessing metadata of 12764166_T ...
# Preprocessing metadata of 12764237_T ...
# Preprocessing metadata of 12764238_T ...
# Preprocessing metadata of 12764239_T ...
# ...
# Preprocessing metadata of 12968682_T ...
# Preprocessing metadata of 12968686_T ...
# Preprocessing metadata of 12968695_T ...
# Preprocessing metadata of 12968697_T ...
# Preprocessing metadata of 12968702_T ...
# Preprocessing metadata of 12968712_T ...
# Preprocessing metadata of 12968714_T ...
# Preprocessing metadata of 12968718_T ...
# Preprocessing metadata of 12968719_T ...
# Preprocessing metadata of 12968720_T ...
# Preprocessing metadata of 12968721_T ...
# Preprocessing metadata of 12968723_T ...
# Preprocessing metadata of 12968727_T ...
# Preprocessing metadata of 12968730_T ...
# Preprocessing metadata of 12968731_T ...
# Preprocessing metadata of 12968733_T ...
# Preprocessing metadata of 12968759_T ...
# Preprocessing metadata of 12968766_T ...
# Preprocessing metadata of 12968767_T ...
# Preprocessing metadata of 12968768_T ...
# Preprocessing metadata of 12968769_T ...
# Preprocessing metadata of 12968773_T ...
# Preprocessing metadata of 12968794_T ...
# Preprocessing metadata of 12968807_T ...
# Preprocessing metadata of 12968810_T ...
# Preprocessing metadata of 12968811_T ...
# Preprocessing metadata of 12968962_T ...
# Preprocessing metadata of 12968997_T ...
# Preprocessing metadata of 12968998_T ...
# Preprocessing metadata of 12969013_T ...
# Preprocessing metadata of 12969015_T ...
# Preprocessing metadata of 12969018_T ...
# Preprocessing metadata of 12969061_T ...
# Preprocessing metadata of 12969104_T ...
# Preprocessing metadata of 12969137_T ...
# Preprocessing metadata of 12969185_T ...
# Preprocessing metadata of 12969191_T ...
# Preprocessing metadata of 12969198_T ...
# Preprocessing metadata of 12969221_T ...
# Preprocessing metadata of 12969223_T ...
# Preprocessing metadata of 12969260_T ...
# Preprocessing metadata of 12969777_T ...
# Preprocessing metadata of 12969966_T ...
# Preprocessing metadata of 12970042_T ...
# Preprocessing metadata of 12970156_T ...
# Preprocessing metadata of 12970158_T ...
# Preprocessing metadata of 12970301_T ...
# Preprocessing metadata of 12970802_T ...
# Preprocessing metadata of 12970927_T ...
# Preprocessing metadata of 12971002_T ...
# Preprocessing metadata of 12971060_T ...
# Preprocessing metadata of 12971068_T ...
# Preprocessing metadata of 12971111_T ...
# Preprocessing metadata of 12971126_T ...
# Preprocessing metadata of 12971133_T ...
# Preprocessing metadata of 12971140_T ...
# Preprocessing metadata of 12971571_T ...
# Preprocessing metadata of 12971882_T ...
# Preprocessing metadata of 12972423_T ...
# Preprocessing metadata of 12972627_T ...
# Preprocessing metadata of 12972795_T ...
# Preprocessing metadata of 12972832_T ...
# Preprocessing metadata of 12972835_T ...
# Preprocessing metadata of 12972836_T ...
# Preprocessing metadata of 12972837_T ...
# Preprocessing metadata of 12972900_T ...
# Preprocessing metadata of 12972917_T ...
# Preprocessing metadata of 12972919_T ...
# Preprocessing metadata of 12972930_T ...
# Preprocessing metadata of 12972951_T ...
# Preprocessing metadata of 12972962_T ...
# Preprocessing metadata of 12972964_T ...
# Preprocessing metadata of 12972965_T ...
# Preprocessing metadata of 12972966_T ...
# Preprocessing metadata of 12972967_T ...
# Preprocessing metadata of 12972973_T ...
# Preprocessing metadata of 12973519_T ...
# Preprocessing metadata of 12973585_T ...
# Preprocessing metadata of 12973599_T ...
# Preprocessing metadata of 12974054_T ...
# Preprocessing metadata of 12976130_T ...
# Preprocessing metadata of 12976131_T ...
# Preprocessing metadata of 12976132_T ...
# Preprocessing metadata of 12976133_T ...
# Preprocessing metadata of 12976187_T ...
# Preprocessing metadata of 12976191_T ...
# Preprocessing metadata of 12976204_T ...
# Preprocessing metadata of 12976273_T ...
# Preprocessing metadata of 12976291_T ...
# Preprocessing metadata of 12976312_T ...
# Preprocessing metadata of 12976327_T ...
# Preprocessing metadata of 12976330_T ...
# Preprocessing metadata of 12976333_T ...
# Preprocessing metadata of 12976334_T ...
# Preprocessing metadata of 12976339_T ...
# Preprocessing metadata of 12976343_T ...
# Preprocessing metadata of 12976347_T ...
# Preprocessing metadata of 12976350_T ...
# Preprocessing metadata of 12976370_T ...
# Preprocessing metadata of 12976382_T ...
# Preprocessing metadata of 12976397_T ...
# Preprocessing metadata of 12976407_T ...
# Preprocessing metadata of 12976410_T ...
# Preprocessing metadata of 12976420_T ...
# Preprocessing metadata of 12976464_T ...
# Preprocessing metadata of 12976466_T ...
# Preprocessing metadata of 12976525_T ...
# Preprocessing metadata of 12976526_T ...
# Preprocessing metadata of 12976527_T ...
# Preprocessing metadata of 12976532_T ...
# Preprocessing metadata of 12976535_T ...
# Preprocessing metadata of 12976537_T ...
# Preprocessing metadata of 12976539_T ...
# Preprocessing metadata of 12976541_T ...
# Preprocessing metadata of 12976542_T ...
# Preprocessing metadata of 12976551_T ...
# Preprocessing metadata of 12976597_T ...
# Preprocessing metadata of 12976634_T ...
# Preprocessing metadata of 12976635_T ...
# Preprocessing metadata of 12976637_T ...
# Preprocessing metadata of 12976644_T ...
# Preprocessing metadata of 12976653_T ...
# Preprocessing metadata of 12976654_T ...
# Preprocessing metadata of 12976655_T ...
# Preprocessing metadata of 12976656_T ...
# Preprocessing metadata of 12976697_T ...
# Preprocessing metadata of 12976723_T ...
# Preprocessing metadata of 12976736_T ...
# Preprocessing metadata of 12976737_T ...
# Preprocessing metadata of 12976739_T ...
# Preprocessing metadata of 12976741_T ...
# Preprocessing metadata of 12976743_T ...
# Preprocessing metadata of 12976754_T ...
# Preprocessing metadata of 12976755_T ...
# Preprocessing metadata of 12976757_T ...
# Preprocessing metadata of 12976758_T ...
# Preprocessing metadata of 12976760_T ...
# Preprocessing metadata of 12976774_T ...
# Preprocessing metadata of 12976775_T ...
# Preprocessing metadata of 12976906_T ...
# Preprocessing metadata of 12976910_T ...
# Preprocessing metadata of 12977526_T ...
# Preprocessing metadata of 12977528_T ...
# Preprocessing metadata of 12977530_T ...
# Preprocessing metadata of 12977570_T ...
# Preprocessing metadata of 12977571_T ...
# Preprocessing metadata of 12977573_T ...
# Preprocessing metadata of 12977626_T ...
# Preprocessing metadata of 12977651_T ...
# Preprocessing metadata of 12977711_T ...
# Preprocessing metadata of 12977723_T ...
# Preprocessing metadata of 12977774_T ...
# Preprocessing metadata of 12977792_T ...
# Preprocessing metadata of 12978051_T ...
# Preprocessing metadata of 12978064_T ...
# Preprocessing metadata of 12978078_T ...
# Preprocessing metadata of 12978140_T ...
# Preprocessing metadata of 12978170_T ...
# Preprocessing metadata of 12978192_T ...
# Preprocessing metadata of 12978213_T ...
# Preprocessing metadata of 12978216_T ...
# Preprocessing metadata of 12978219_T ...
# Preprocessing metadata of 12978240_T ...
# Preprocessing metadata of 12978244_T ...
# Preprocessing metadata of 12978249_T ...
# Preprocessing metadata of 12978256_T ...
# Preprocessing metadata of 12978260_T ...
# Preprocessing metadata of 12978264_T ...
# Preprocessing metadata of 12978289_T ...
# Preprocessing metadata of 12978341_T ...
# Preprocessing metadata of 12978342_T ...
# Preprocessing metadata of 12978359_T ...
# Preprocessing metadata of 12978373_T ...
# Preprocessing metadata of 12978389_T ...
# Preprocessing metadata of 12978416_T ...
# Preprocessing metadata of 12978452_T ...
# Preprocessing metadata of 12978456_T ...
# Preprocessing metadata of 12978468_T ...
# Preprocessing metadata of 12978471_T ...
# Preprocessing metadata of 12978472_T ...
# Preprocessing metadata of 12978474_T ...
# Preprocessing metadata of 12978475_T ...
# Preprocessing metadata of 12978476_T ...
# Preprocessing metadata of 12978477_T ...
# Preprocessing metadata of 12978480_T ...
# Preprocessing metadata of 12978481_T ...
# Preprocessing metadata of 12978482_T ...
# Preprocessing metadata of 12978483_T ...
# Preprocessing metadata of 12978484_T ...
# Preprocessing metadata of 12978487_T ...
# Preprocessing metadata of 12978488_T ...
# Preprocessing metadata of 12978502_T ...
# Preprocessing metadata of 12978512_T ...
# Preprocessing metadata of 12978515_T ...
# Preprocessing metadata of 12978516_T ...
# Preprocessing metadata of 12978524_T ...
# Preprocessing metadata of 12978526_T ...
# Preprocessing metadata of 12978529_T ...
# Preprocessing metadata of 12978547_T ...
# Preprocessing metadata of 12978602_T ...
# Preprocessing metadata of 12978680_T ...
# Preprocessing metadata of 12978715_T ...
# Preprocessing metadata of 12978771_T ...
# Preprocessing metadata of 12978788_T ...
# Preprocessing metadata of 12978826_T ...
# Preprocessing metadata of 12978850_T ...
# Preprocessing metadata of 12978858_T ...
# Preprocessing metadata of 12978861_T ...
# Preprocessing metadata of 12978863_T ...
# Preprocessing metadata of 12978865_T ...
# Preprocessing metadata of 12978867_T ...
# Preprocessing metadata of 12978869_T ...
# Preprocessing metadata of 12978871_T ...
# Preprocessing metadata of 12978872_T ...
# Preprocessing metadata of 12978873_T ...
# Preprocessing metadata of 12978874_T ...
# Preprocessing metadata of 12978875_T ...
# Preprocessing metadata of 12978876_T ...
# Preprocessing metadata of 12978877_T ...
# Preprocessing metadata of 12978878_T ...
# Preprocessing metadata of 12978879_T ...
# Preprocessing metadata of 12978880_T ...
# Preprocessing metadata of 12978881_T ...
# Preprocessing metadata of 12978885_T ...
# Preprocessing metadata of 12978888_T ...
# Preprocessing metadata of 12978890_T ...
# Preprocessing metadata of 12978891_T ...
# Preprocessing metadata of 12978892_T ...
# Preprocessing metadata of 12978893_T ...
# Preprocessing metadata of 12978894_T ...
# Preprocessing metadata of 12978895_T ...
# Preprocessing metadata of 12978896_T ...
# Preprocessing metadata of 12978897_T ...
# Preprocessing metadata of 12978903_T ...
# Preprocessing metadata of 12978916_T ...
# Preprocessing metadata of 12978925_T ...
# Preprocessing metadata of 12978946_T ...
# Preprocessing metadata of 12978949_T ...
# Preprocessing metadata of 12978953_T ...
# Preprocessing metadata of 12978959_T ...
# Preprocessing metadata of 12978977_T ...
# Preprocessing metadata of 12978986_T ...
# Preprocessing metadata of 12978995_T ...
# Preprocessing metadata of 12978998_T ...
# Preprocessing metadata of 12979007_T ...
# Preprocessing metadata of 12979018_T ...
# Preprocessing metadata of 12979027_T ...
# Preprocessing metadata of 12979055_T ...
# Preprocessing metadata of 12979078_T ...
# Preprocessing metadata of 12979090_T ...
# Preprocessing metadata of 12979091_T ...
# Preprocessing metadata of 12979136_T ...
# Preprocessing metadata of 12979155_T ...
# Preprocessing metadata of 12979156_T ...
# Preprocessing metadata of 12979187_T ...
# Preprocessing metadata of 12979195_T ...
# Preprocessing metadata of 12979220_T ...
# Preprocessing metadata of 12979241_T ...
# Preprocessing metadata of 12979261_T ...
# Preprocessing metadata of 12979273_T ...
# Preprocessing metadata of 12979393_T ...
# Preprocessing metadata of 12979441_T ...
# Preprocessing metadata of 12979495_T ...
# Preprocessing metadata of 12979649_T ...
# Preprocessing metadata of 12979680_T ...
# Preprocessing metadata of 12979850_T ...
# Preprocessing metadata of 12980054_T ...
# Preprocessing metadata of 12980082_T ...
# Preprocessing metadata of 12980098_T ...
# Preprocessing metadata of 12980099_T ...
# Preprocessing metadata of 12980104_T ...
# Preprocessing metadata of 12980111_T ...
# Preprocessing metadata of 12980115_T ...
# Preprocessing metadata of 12980125_T ...
# Preprocessing metadata of 12980177_T ...
# Preprocessing metadata of 12980186_T ...
# Preprocessing metadata of 12980187_T ...
# Preprocessing metadata of 12980207_T ...
# Preprocessing metadata of 12980240_T ...
# Preprocessing metadata of 12980265_T ...
# Preprocessing metadata of 12980267_T ...
# Preprocessing metadata of 12980268_T ...
# Preprocessing metadata of 12980281_T ...
# Preprocessing metadata of 12980282_T ...
# Preprocessing metadata of 12980290_T ...
# Preprocessing metadata of 12980317_T ...
# Preprocessing metadata of 12980326_T ...
# Preprocessing metadata of 12980338_T ...
# Preprocessing metadata of 12980344_T ...
# Preprocessing metadata of 12980378_T ...
# Preprocessing metadata of 12980381_T ...
# Preprocessing metadata of 12980427_T ...
# Preprocessing metadata of 12980430_T ...
# Preprocessing metadata of 12980431_T ...
# Preprocessing metadata of 12980432_T ...
# Preprocessing metadata of 12980445_T ...
# Preprocessing metadata of 12980470_T ...
# Preprocessing metadata of 12980496_T ...
# Preprocessing metadata of 12980497_T ...
# Preprocessing metadata of 12980498_T ...
# Preprocessing metadata of 12980508_T ...
# Preprocessing metadata of 12980515_T ...
# Preprocessing metadata of 12980518_T ...
# Preprocessing metadata of 12980522_T ...
# Preprocessing metadata of 12980523_T ...
# Preprocessing metadata of 12980524_T ...
# Preprocessing metadata of 12980525_T ...
# Preprocessing metadata of 12980526_T ...
# Preprocessing metadata of 12980527_T ...
# Preprocessing metadata of 12980533_T ...
# Preprocessing metadata of 12980537_T ...
# Preprocessing metadata of 12980544_T ...
# Preprocessing metadata of 12980545_T ...
# Preprocessing metadata of 12980546_T ...
# Preprocessing metadata of 12980547_T ...
# Preprocessing metadata of 12980549_T ...
# Preprocessing metadata of 12980550_T ...
# Preprocessing metadata of 12980551_T ...
# Preprocessing metadata of 12980553_T ...
# Preprocessing metadata of 12980605_T ...
# Preprocessing metadata of 12980610_T ...
# Preprocessing metadata of 12980657_T ...
# Preprocessing metadata of 12980658_T ...
# Preprocessing metadata of 12980660_T ...
# Preprocessing metadata of 12980661_T ...
# Preprocessing metadata of 12980662_T ...
# Preprocessing metadata of 12980663_T ...
# Preprocessing metadata of 12980667_T ...
# Preprocessing metadata of 12980669_T ...
# Preprocessing metadata of 12980670_T ...
# Preprocessing metadata of 12981932_T ...
# Preprocessing metadata of 12981935_T ...
# Preprocessing metadata of 12981940_T ...
# Preprocessing metadata of 12981943_T ...
# Preprocessing metadata of 12981946_T ...
# Preprocessing metadata of 12981950_T ...
# Preprocessing metadata of 12981951_T ...
# Preprocessing metadata of 12981954_T ...
# Preprocessing metadata of 12981955_T ...
# Preprocessing metadata of 12981956_T ...
# Preprocessing metadata of 12981960_T ...
# Preprocessing metadata of 12981967_T ...
# Preprocessing metadata of 12981977_T ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 17
#      15 for f in files_in_dir:
#      16     if f.lower().endswith('.xml'):
# ---> 17         read_xml(f,i)
#      18     i = i + 1
#      20 # Metadata from dataframe as csv
#
# Cell In[3], line 36, in read_xml(document, index)
#      34   # get year
#      35   df['date'] = pd.to_datetime(df['date'])
# ---> 36   df['year'] = df['date'].dt.year
#      37   df['year'] = df['year'].astype(int)
#      38 else:
#
# File c:\Users\hkpu\anaconda3\envs\index\lib\site-packages\pandas\core\accessor.py:80, in PandasDelegate._add_delegate_accessors.<locals>._create_delegator_property.<locals>._getter(self)
#      79 def _getter(self):
# ---> 80     return self._delegate_property_get(name)
#
# File c:\Users\hkpu\anaconda3\envs\index\lib\site-packages\pandas\core\indexes\accessors.py:87, in Properties._delegate_property_get(self, name)
#      83 from pandas import Series
#      85 values = self._get_values()
# ---> 87 result = getattr(values, name)
#      89 # maybe need to upcast (ints)
#      90 if isinstance(result, np.ndarray):
#
# File c:\Users\hkpu\anaconda3\envs\index\lib\site-packages\pandas\core\indexes\extension.py:71, in _inherit_from_data.<locals>.fget(self)
#      70 def fget(self):
# ---> 71     result = getattr(self._data, name)
#      72     if wrap:
#      73         if isinstance(result, type(self._data)):
#
# File c:\Users\hkpu\anaconda3\envs\index\lib\site-packages\pandas\core\arrays\datetimes.py:141, in _field_accessor.<locals>.f(self)
#     138     result = self._maybe_mask_results(result, fill_value=None)
#     140 else:
# --> 141     result = fields.get_date_field(values, field, reso=self._reso)
#     142     result = self._maybe_mask_results(
#     143         result, fill_value=None, convert="float64"
#     144     )
#     146 return result
#
# KeyboardInterrupt:

# %%
#####################################################

# processing pdf to text
def read_pdf(document, index=0):

  # add filename to dataframe
  m = re.search(r"\\(?!.*\\)(.*)((\.pdf))", document)
  filename_match = m.group(0)
  filename = re.sub("[\\\/\'\>]", "", filename_match)
  filename = re.sub("\.\w+", "", filename)
  df.loc[index, 'file'] = filename
  
  print("Preprocessing", filename, "...")

  # creating a pdf file object
  pdf = open(document, 'rb') 

  # creating a pdf reader object 
  reader = PyPDF2.PdfReader(pdf, strict=False) 
      
  # printing number of pages in pdf file 
  # print("Number of pages:", pdfReader.numPages)
  pages = len(reader.pages)

  # creating a page object 
  page = reader.pages[0]

  # extracting text from page 
  # print(pageObj.extractText())

  pages_with_contents = []

  for p in range(pages):
    page = reader.pages[p]
    page_contents = page.extract_text()
    pages_with_contents.append(page_contents)

  # join pages into one document
  contents = " ".join(pages_with_contents)

  #closing the pdf file object 
  pdf.close() 

  # cleaning
  contents = re.sub("\n", " ", contents)
  contents = re.sub("\r", " ", contents)
  contents = re.sub("\t", " ", contents)

  # remove symbols
  # contents = re.sub(r"[^a-zA-Z0-9]", " ", contents)

  # # lowercase
  # contents = contents.lower()

  #remove extra spaces
  contents = re.sub("\s+", " ", contents)

  # add contents to dataframe
  df.loc[index, 'content'] = contents

  return
# Out:
# Preprocessing 1004063_T ...
# Preprocessing 10103972_T ...
# Preprocessing 1012763_T ...
# Preprocessing 1012782_T ...
# Preprocessing 1012785_T ...
# Preprocessing 1012787_T ...
# Preprocessing 1020948_T ...
# Preprocessing 10221377_T ...
# Preprocessing 10229958_T ...
# Preprocessing 10231130_T ...
# Preprocessing 10276652_T ...
# Preprocessing 10305562_T ...
# Preprocessing 10341258_T ...
# Preprocessing 10353489_T ...
# Preprocessing 10354189_T ...
# Preprocessing 1037620_T ...
# Preprocessing 10382650_T ...
# Preprocessing 10406938_T ...
# Preprocessing 10418964_T ...
# Preprocessing 10426026_T ...
# Preprocessing 1048657_T ...
# Preprocessing 10550671_T ...
# Preprocessing 1065361_T ...
# Preprocessing 1065377_T ...
# Preprocessing 10655690_T ...
# Preprocessing 10659595_T ...
# Preprocessing 10679258_T ...
# Preprocessing 10687439_T ...
# Preprocessing 10689602_T ...
# Preprocessing 10724780_T ...
# Preprocessing 10733834_T ...
# Preprocessing 10748343_T ...
# Preprocessing 10749089_T ...
# Preprocessing 10749091_T ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 71
#      69 for f in files_in_dir:
#      70     if f.lower().endswith('.pdf'):
# ---> 71         read_pdf(f,i)
#      72         j = j + 1
#      73     i = i + 1
#
# Cell In[5], line 42, in read_pdf(document, index)
#      39 contents = " ".join(pages_with_contents)
#      41 #closing the pdf file object
# ---> 42 pdf.close()
#      44 # cleaning
#      45 contents = re.sub("\n", " ", contents)
#
# KeyboardInterrupt:

# %%
# initialize dataframe to hold documents
df = pd.DataFrame(columns=['file'])

# iterate over files in the directory
i = 0
j = 0
for f in files_in_dir:
    if f.lower().endswith('.pdf'):
        read_pdf(f,i)
        j = j + 1
    i = i + 1

df.reset_index(inplace=True)

# Sanity check
# df['content'][0]

# Documents from dataframe as txt
print("Creating documents.txt...")
documents = ""
for index, row in df.iterrows():
    document_string = row['content']
    # if index == j-1:
    #   documents = documents + document_string
    # else:
    documents = documents + document_string + '\n'

with open(path + '\\input\\documents.txt', 'w') as f:
    f.write(documents)
